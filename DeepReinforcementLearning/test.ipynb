# %%
import numpy as np
import gym
import pandas as pd
import tensorflow
from keras.layers import Dense, Activation, Flatten
from keras.models import Sequential, load_model
from tensorflow.keras.optimizers import Adam
import numpy as np

# %%
class ReplayBuffer(object):
    def __init__(self, max_size, input_dims):
        self.mem_size = max_size
        self.mem_cntr = 0
        self.state_memory = np.zeros((self.mem_size, *input_dims), dtype=np.float32)
        self.new_state_memory = np.zeros((self.mem_size, *input_dims), dtype=np.float32)     
        self.action_memory = np.zeros((self.mem_size), dtype=np.int32)
        self.reward_memory = np.zeros(self.mem_size, dtype=np.int32)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.int32)
    
    def store_transition(self, state, action, reward, state_, done):
        index = self.mem_cntr % self.mem_size
        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.reward_memory[index] = reward
        self.terminal_memory[index] = 1 - int(done)
        self.action_memory[index] = action
        self.mem_cntr += 1
        
    def sample_buffer(self, batch_size):
        max_mem = min(self.mem_cntr, self.mem_size)
        batch = np.random.choice(max_mem, batch_size, replace=False)
        
        states = self.state_memory[batch]
        states_ = self.new_state_memory[batch]
        rewards = self.reward_memory[batch]
        actions = self.action_memory[batch]
        terminal = self.terminal_memory[batch]
        
        return states, actions, rewards, states_, terminal
    
def build_dqn(lr, n_actions, input_dims, fc1_dims, fc2_dims):
    model = Sequential([
                Flatten(input_shape=(input_dims)),
                Dense(fc1_dims),
                Activation('relu'),
                Dense(fc2_dims),
                Activation('relu'),
                Dense(n_actions)])
    
    model.compile(optimizer=Adam(learning_rate=lr), loss='mse')
    return model

class Agent(object):
    def __init__(self, alpha, gamma, n_actions, epsilon, batch_size, input_dims,
                 epsilon_dec=0.994, epsilon_end=0.01, epsilon_method='log',                 
                 update_method='hard_copy', tau=0.01, replace_target=100,
                 mem_size=500000):
        self.action_space = [i for i in range(n_actions)]
        self.n_actions = n_actions
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_dec = epsilon_dec
        self.epsilon_min = epsilon_end
        self.epsilon_method = epsilon_method
        self.batch_size = batch_size        
        self.memory = ReplayBuffer(mem_size, input_dims)
        self.update_method = update_method
        self.tau = tau
        self.replace_target = replace_target
        
        self.q_eval = build_dqn(alpha, n_actions, input_dims, 32, 64)
        self.q_target = build_dqn(alpha, n_actions, input_dims, 32, 64)
        
        
    def remember(self, state, action, reward, new_state, done):
        self.memory.store_transition(state, action, reward, new_state, done)
        
    def choose_action(self, state):
        state = state[np.newaxis, :]
        if np.random.random() < self.epsilon: action = np.random.choice(self.action_space)
        else:
            actions = self.q_eval.predict(state)
            action = np.argmax(actions)
            
        return action
    
    def learn(self):
        if self.memory.mem_cntr < self.batch_size: return
        
        states, actions, rewards, states_, dones = self.memory.sample_buffer(self.batch_size)
        
        q_next = self.q_target.predict(states_)
        q_eval = self.q_eval.predict(states_)
        q_target = self.q_eval.predict(states)
        
        max_actions = np.argmax(q_eval, axis=1)
        
        batch_index = np.arange(self.batch_size, dtype=np.int32)
        
        q_target[batch_index, actions] = rewards + self.gamma*q_next[batch_index, max_actions.astype(int)]*dones
                                
        self.q_eval.fit(states, q_target, verbose=0)    #q_eval hálózat tanítása
        
        self.update_network_parameters()                #q_target hálózat tanítása
            
    
    def update_network_parameters(self):
        #Periodikus hard-copy
        if self.memory.mem_cntr % self.replace_target == 0 and self.update_method == 'hard_copy':
            self.q_target.set_weights(self.q_eval.get_weights())
        
        #Polyak averaging
        if self.update_method == 'polyak':
            q_e = np.array(self.q_eval.get_weights())
            q_t = np.array(self.q_target.get_weights())
            self.q_target.set_weights(0.01*q_e + (1. - 0.01)*q_t)
        
    def update_epsilon(self):
        if self.epsilon_method == 'log': self.epsilon = self.epsilon*self.epsilon_dec if self.epsilon > self.epsilon_min else self.epsilon_min
        if self.epsilon_method == 'linear': self.epsilon = self.epsilon-self.epsilon_dec if self.epsilon > self.epsilon_min else self.epsilon_min
                                
    def save_model(self, fname = 'ddqn_model.h5'):
        self.q_eval.save(fname)
        
    def load_model(self, fname = 'ddqn_model.h5'):
        self.q_eval = load_model(fname)
        if self.epsilon == 0.0: self.update_network_parameters()

# %%
#Paraméterek:
env = gym.make('MountainCar-v0')
n_games = 1000                      # epizódok száma
max_steps = 500                     # egy epizódon belüli lépések maximális száma
alpha = 0.0005                      # neurális háló tanulási sebessége
gamma = 0.99                        # diszkonttényező jutalom számításánál
epsilon = 1.0                       # random cselekvés valószínűsége az első epizódban
epsilon_dec = 0.002                 # linear esetén levonjuk / log esetén beszorozzuk vele az előző értéket
epsilon_dec_method = 'linear'       # log és linear van egyelőre
epsilon_min = 0.01    
mem_size = 1000000                  # mennyi állapotváltozást tárolhat maximum a memóriában
batch_size = 64                     # ekkora kötegeken tanul a neurális háló
network_update_method = 'polyak'    # polyak vagy hard-copy
tau = 0.01                          # Csak a polyak esetén
replace_target = 100                # Csak hard-copy esetén, milyen időközönként frissitse a target hálózatot

#Ágens létrehozása, modell betöltése -ha kell-
agent = Agent(alpha=alpha, gamma=gamma, epsilon=epsilon, epsilon_dec=epsilon_dec,
                epsilon_end=epsilon_min, epsilon_method=epsilon_dec_method,
                input_dims=env.observation_space.shape, n_actions=env.action_space.n,
                mem_size=mem_size, batch_size=batch_size,
                update_method=network_update_method, tau=tau, replace_target=replace_target)

#   agent.load_model(fname = 'dqn_model.h5')   

scores = []
eps_history = []
ma100 = []

#Tanítás
for i in range(n_games):
    done = False
    score = 0
    #step_counter = 0
    observation = env.reset()
    
    for step in range(max_steps):
        #env.render()
        action = agent.choose_action(observation)
        observation_, reward, done, info = env.step(action)
        #step_counter += 1
        score += reward
        agent.remember(observation, action, reward, observation_, done)
        observation = observation_
        agent.learn()
        if done:
            break

    scores.append(round(score,4))   
    avg_score = np.mean(scores[max(0, i-100):(i+1)])
    ma100.append(round(avg_score,4))
    eps_history.append(round(agent.epsilon,4))
    
    print('episode', i+1,
            'epsilon %.2f' % agent.epsilon,
            #'steps', step_counter,
            'score %.2f' % score,
            'ma100 %.2f' % avg_score)
        
    if (i+1) % 500 == 0 and i > 0:            
        agent.save_model(fname = 'ddqn_model' + str(i+1) +'.h5')
    
    if avg_score > 200:
        agent.save_model(fname = 'ddqn_model' + str(i+1) +'.h5')
        break
    
    if(i%10==0):
        print("Episode:"+str(i)+" Average score"+str(avg_score))

    agent.update_epsilon()
    
result_df = pd.DataFrame({'Score':scores, 'MA100':ma100, 'Epsilon':eps_history})
result_df.to_csv("ddqn_results.csv")
env.close()
# Out:
# C:\Users\DANIEL~1\AppData\Local\Temp/ipykernel_15052/3807724093.py:105: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   q_e = np.array(self.q_eval.get_weights())
# C:\Users\DANIEL~1\AppData\Local\Temp/ipykernel_15052/3807724093.py:106: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   q_t = np.array(self.q_target.get_weights())
# episode 1 epsilon 1.00 score -200.00 ma100 -200.00
# Episode:0 Average score-200.0
# episode 2 epsilon 1.00 score -200.00 ma100 -200.00
# episode 3 epsilon 1.00 score -200.00 ma100 -200.00
# episode 4 epsilon 0.99 score -200.00 ma100 -200.00
# episode 5 epsilon 0.99 score -200.00 ma100 -200.00
# episode 6 epsilon 0.99 score -200.00 ma100 -200.00
# episode 7 epsilon 0.99 score -200.00 ma100 -200.00
# episode 8 epsilon 0.99 score -200.00 ma100 -200.00
# episode 9 epsilon 0.98 score -200.00 ma100 -200.00
# episode 10 epsilon 0.98 score -200.00 ma100 -200.00
# episode 11 epsilon 0.98 score -200.00 ma100 -200.00
# Episode:10 Average score-200.0
# episode 12 epsilon 0.98 score -200.00 ma100 -200.00
# episode 13 epsilon 0.98 score -200.00 ma100 -200.00
# episode 14 epsilon 0.97 score -200.00 ma100 -200.00
# episode 15 epsilon 0.97 score -200.00 ma100 -200.00
# episode 16 epsilon 0.97 score -200.00 ma100 -200.00
# episode 17 epsilon 0.97 score -200.00 ma100 -200.00
# episode 18 epsilon 0.97 score -200.00 ma100 -200.00
# episode 19 epsilon 0.96 score -200.00 ma100 -200.00
# episode 20 epsilon 0.96 score -200.00 ma100 -200.00
# episode 21 epsilon 0.96 score -200.00 ma100 -200.00
# Episode:20 Average score-200.0
# episode 22 epsilon 0.96 score -200.00 ma100 -200.00
# episode 23 epsilon 0.96 score -200.00 ma100 -200.00
# episode 24 epsilon 0.95 score -200.00 ma100 -200.00
# episode 25 epsilon 0.95 score -200.00 ma100 -200.00
# episode 26 epsilon 0.95 score -200.00 ma100 -200.00
# episode 27 epsilon 0.95 score -200.00 ma100 -200.00
# episode 28 epsilon 0.95 score -200.00 ma100 -200.00
# episode 29 epsilon 0.94 score -200.00 ma100 -200.00
# episode 30 epsilon 0.94 score -200.00 ma100 -200.00
# episode 31 epsilon 0.94 score -200.00 ma100 -200.00
# Episode:30 Average score-200.0
# episode 32 epsilon 0.94 score -200.00 ma100 -200.00
# episode 33 epsilon 0.94 score -200.00 ma100 -200.00
# episode 34 epsilon 0.93 score -200.00 ma100 -200.00
# episode 35 epsilon 0.93 score -200.00 ma100 -200.00
# episode 36 epsilon 0.93 score -200.00 ma100 -200.00
# episode 37 epsilon 0.93 score -200.00 ma100 -200.00
# episode 38 epsilon 0.93 score -200.00 ma100 -200.00
# episode 39 epsilon 0.92 score -200.00 ma100 -200.00
# episode 40 epsilon 0.92 score -200.00 ma100 -200.00
# episode 41 epsilon 0.92 score -200.00 ma100 -200.00
# Episode:40 Average score-200.0
# episode 42 epsilon 0.92 score -200.00 ma100 -200.00
# episode 43 epsilon 0.92 score -200.00 ma100 -200.00
# episode 44 epsilon 0.91 score -200.00 ma100 -200.00
# episode 45 epsilon 0.91 score -200.00 ma100 -200.00
# episode 46 epsilon 0.91 score -200.00 ma100 -200.00
# episode 47 epsilon 0.91 score -200.00 ma100 -200.00
# episode 48 epsilon 0.91 score -200.00 ma100 -200.00
# episode 49 epsilon 0.90 score -200.00 ma100 -200.00
# episode 50 epsilon 0.90 score -200.00 ma100 -200.00
# episode 51 epsilon 0.90 score -200.00 ma100 -200.00
# Episode:50 Average score-200.0
# episode 52 epsilon 0.90 score -200.00 ma100 -200.00
# episode 53 epsilon 0.90 score -200.00 ma100 -200.00
# episode 54 epsilon 0.89 score -200.00 ma100 -200.00
# episode 55 epsilon 0.89 score -200.00 ma100 -200.00
# episode 56 epsilon 0.89 score -200.00 ma100 -200.00
# episode 57 epsilon 0.89 score -200.00 ma100 -200.00
# episode 58 epsilon 0.89 score -200.00 ma100 -200.00
# episode 59 epsilon 0.88 score -200.00 ma100 -200.00
# episode 60 epsilon 0.88 score -200.00 ma100 -200.00
# episode 61 epsilon 0.88 score -200.00 ma100 -200.00
# Episode:60 Average score-200.0
# episode 62 epsilon 0.88 score -200.00 ma100 -200.00
# episode 63 epsilon 0.88 score -200.00 ma100 -200.00
# episode 64 epsilon 0.87 score -200.00 ma100 -200.00
# episode 65 epsilon 0.87 score -200.00 ma100 -200.00
# episode 66 epsilon 0.87 score -200.00 ma100 -200.00
# episode 67 epsilon 0.87 score -200.00 ma100 -200.00
# episode 68 epsilon 0.87 score -200.00 ma100 -200.00
# episode 69 epsilon 0.86 score -200.00 ma100 -200.00
# episode 70 epsilon 0.86 score -200.00 ma100 -200.00
# episode 71 epsilon 0.86 score -200.00 ma100 -200.00
# Episode:70 Average score-200.0
# episode 72 epsilon 0.86 score -200.00 ma100 -200.00
# episode 73 epsilon 0.86 score -200.00 ma100 -200.00
# episode 74 epsilon 0.85 score -200.00 ma100 -200.00
# episode 75 epsilon 0.85 score -200.00 ma100 -200.00
# episode 76 epsilon 0.85 score -200.00 ma100 -200.00
# episode 77 epsilon 0.85 score -200.00 ma100 -200.00
# episode 78 epsilon 0.85 score -200.00 ma100 -200.00
# episode 79 epsilon 0.84 score -200.00 ma100 -200.00
# episode 80 epsilon 0.84 score -200.00 ma100 -200.00
# episode 81 epsilon 0.84 score -200.00 ma100 -200.00
# Episode:80 Average score-200.0
# episode 82 epsilon 0.84 score -200.00 ma100 -200.00
# episode 83 epsilon 0.84 score -200.00 ma100 -200.00
# episode 84 epsilon 0.83 score -200.00 ma100 -200.00
# episode 85 epsilon 0.83 score -200.00 ma100 -200.00
# episode 86 epsilon 0.83 score -200.00 ma100 -200.00
# episode 87 epsilon 0.83 score -200.00 ma100 -200.00
# episode 88 epsilon 0.83 score -200.00 ma100 -200.00
# episode 89 epsilon 0.82 score -200.00 ma100 -200.00
# episode 90 epsilon 0.82 score -200.00 ma100 -200.00
# episode 91 epsilon 0.82 score -200.00 ma100 -200.00
# Episode:90 Average score-200.0
# episode 92 epsilon 0.82 score -200.00 ma100 -200.00
# episode 93 epsilon 0.82 score -200.00 ma100 -200.00
# episode 94 epsilon 0.81 score -200.00 ma100 -200.00
# episode 95 epsilon 0.81 score -200.00 ma100 -200.00
# episode 96 epsilon 0.81 score -200.00 ma100 -200.00
# episode 97 epsilon 0.81 score -200.00 ma100 -200.00
# episode 98 epsilon 0.81 score -200.00 ma100 -200.00
# episode 99 epsilon 0.80 score -200.00 ma100 -200.00
# episode 100 epsilon 0.80 score -200.00 ma100 -200.00
# episode 101 epsilon 0.80 score -200.00 ma100 -200.00
# Episode:100 Average score-200.0
# episode 102 epsilon 0.80 score -200.00 ma100 -200.00
# episode 103 epsilon 0.80 score -200.00 ma100 -200.00
# episode 104 epsilon 0.79 score -200.00 ma100 -200.00
# episode 105 epsilon 0.79 score -200.00 ma100 -200.00
# episode 106 epsilon 0.79 score -200.00 ma100 -200.00
# episode 107 epsilon 0.79 score -200.00 ma100 -200.00
# episode 108 epsilon 0.79 score -200.00 ma100 -200.00
# episode 109 epsilon 0.78 score -200.00 ma100 -200.00
# episode 110 epsilon 0.78 score -200.00 ma100 -200.00
# episode 111 epsilon 0.78 score -200.00 ma100 -200.00
# Episode:110 Average score-200.0
# episode 112 epsilon 0.78 score -200.00 ma100 -200.00
# episode 113 epsilon 0.78 score -200.00 ma100 -200.00
# episode 114 epsilon 0.77 score -200.00 ma100 -200.00
# episode 115 epsilon 0.77 score -200.00 ma100 -200.00
# episode 116 epsilon 0.77 score -200.00 ma100 -200.00
# episode 117 epsilon 0.77 score -200.00 ma100 -200.00
# episode 118 epsilon 0.77 score -200.00 ma100 -200.00
# episode 119 epsilon 0.76 score -200.00 ma100 -200.00
# episode 120 epsilon 0.76 score -200.00 ma100 -200.00
# episode 121 epsilon 0.76 score -200.00 ma100 -200.00
# Episode:120 Average score-200.0
# episode 122 epsilon 0.76 score -200.00 ma100 -200.00
# episode 123 epsilon 0.76 score -200.00 ma100 -200.00
# episode 124 epsilon 0.75 score -200.00 ma100 -200.00
# episode 125 epsilon 0.75 score -200.00 ma100 -200.00
# episode 126 epsilon 0.75 score -200.00 ma100 -200.00
# episode 127 epsilon 0.75 score -200.00 ma100 -200.00
# episode 128 epsilon 0.75 score -200.00 ma100 -200.00
# episode 129 epsilon 0.74 score -200.00 ma100 -200.00
# episode 130 epsilon 0.74 score -200.00 ma100 -200.00
# episode 131 epsilon 0.74 score -200.00 ma100 -200.00
# Episode:130 Average score-200.0
# episode 132 epsilon 0.74 score -200.00 ma100 -200.00
# episode 133 epsilon 0.74 score -200.00 ma100 -200.00
# episode 134 epsilon 0.73 score -200.00 ma100 -200.00
# episode 135 epsilon 0.73 score -200.00 ma100 -200.00
# episode 136 epsilon 0.73 score -200.00 ma100 -200.00
# episode 137 epsilon 0.73 score -200.00 ma100 -200.00
# episode 138 epsilon 0.73 score -200.00 ma100 -200.00
# episode 139 epsilon 0.72 score -200.00 ma100 -200.00
# episode 140 epsilon 0.72 score -200.00 ma100 -200.00
# episode 141 epsilon 0.72 score -200.00 ma100 -200.00
# Episode:140 Average score-200.0
# episode 142 epsilon 0.72 score -200.00 ma100 -200.00
# episode 143 epsilon 0.72 score -200.00 ma100 -200.00
# episode 144 epsilon 0.71 score -200.00 ma100 -200.00
# episode 145 epsilon 0.71 score -200.00 ma100 -200.00
# episode 146 epsilon 0.71 score -200.00 ma100 -200.00
# episode 147 epsilon 0.71 score -200.00 ma100 -200.00
# episode 148 epsilon 0.71 score -200.00 ma100 -200.00
# episode 149 epsilon 0.70 score -200.00 ma100 -200.00
# episode 150 epsilon 0.70 score -200.00 ma100 -200.00
# episode 151 epsilon 0.70 score -200.00 ma100 -200.00
# Episode:150 Average score-200.0
# episode 152 epsilon 0.70 score -200.00 ma100 -200.00
# episode 153 epsilon 0.70 score -200.00 ma100 -200.00
# episode 154 epsilon 0.69 score -200.00 ma100 -200.00
# episode 155 epsilon 0.69 score -200.00 ma100 -200.00
# episode 156 epsilon 0.69 score -200.00 ma100 -200.00
# episode 157 epsilon 0.69 score -200.00 ma100 -200.00
# episode 158 epsilon 0.69 score -200.00 ma100 -200.00
# episode 159 epsilon 0.68 score -200.00 ma100 -200.00
# episode 160 epsilon 0.68 score -200.00 ma100 -200.00
# episode 161 epsilon 0.68 score -200.00 ma100 -200.00
# Episode:160 Average score-200.0
# episode 162 epsilon 0.68 score -200.00 ma100 -200.00
# episode 163 epsilon 0.68 score -200.00 ma100 -200.00
# episode 164 epsilon 0.67 score -200.00 ma100 -200.00
# episode 165 epsilon 0.67 score -200.00 ma100 -200.00
# episode 166 epsilon 0.67 score -200.00 ma100 -200.00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\DANIEL~1\AppData\Local\Temp/ipykernel_15052/4022236300.py in <module>
#      43         agent.remember(observation, action, reward, observation_, done)
#      44         observation = observation_
# ---> 45         agent.learn()
#      46         if done:
#      47             break
#
# C:\Users\DANIEL~1\AppData\Local\Temp/ipykernel_15052/3807724093.py in learn(self)
#      83         q_next = self.q_target.predict(states_)
#      84         q_eval = self.q_eval.predict(states_)
# ---> 85         q_target = self.q_eval.predict(states)
#      86
#      87         max_actions = np.argmax(q_eval, axis=1)
#
# c:\Users\Daniel Kuknyo\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\Daniel Kuknyo\anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1949               stacklevel=2)
#    1950
# -> 1951       data_handler = data_adapter.get_data_handler(
#    1952           x=x,
#    1953           batch_size=batch_size,
#
# c:\Users\Daniel Kuknyo\anaconda3\lib\site-packages\keras\engine\data_adapter.py in get_data_handler(*args, **kwargs)
#    1397   if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1398     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1399   return DataHandler(*args, **kwargs)
#    1400
#    1401
#
# c:\Users\Daniel Kuknyo\anaconda3\lib\site-packages\keras\engine\data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1147
#    1148     adapter_cls = select_data_adapter(x, y)
# -> 1149     self._adapter = adapter_cls(
#    1150         x,
#    1151         y,
#
# c:\Users\Daniel Kuknyo\anaconda3\lib\site-packages\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     324       return flat_dataset
#     325
# --> 326     indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     327
#     328     dataset = self.slice_inputs(indices_dataset, inputs)
#
# c:\Users\Daniel Kuknyo\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in flat_map(self, map_func, name)
#    2058       Dataset: A `Dataset`.
#    2059     """
# -> 2060     return FlatMapDataset(self, map_func, name=name)
#    2061
#    2062   def interleave(self,
#
# c:\Users\Daniel Kuknyo\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __init__(self, input_dataset, map_func, name)
#    5277     """See `Dataset.flat_map()` for details."""
#    5278     self._input_dataset = input_dataset
# -> 5279     self._map_func = structured_function.StructuredFunctionWrapper(
#    5280         map_func, self._transformation_name(), dataset=input_dataset)
#    5281     if not isinstance(self._map_func.output_structure, DatasetSpec):
#
# c:\Users\Daniel Kuknyo\anaconda3\lib\site-packages\tensorflow\python\data\ops\structured_function.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     269         fn_factory = trace_tf_function(defun_kwargs)
#     270
# --> 271     self._function = fn_factory()
#     272     # There is no graph to add in eager mode.
#     273     add_to_graph &= not context.executing_eagerly()
#
# c:\Users\Daniel Kuknyo\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in get_concrete_function(self, *args, **kwargs)
#    3068          or `tf.Tensor` or `tf.TensorSpec`.
#    3069     """
# -> 3070     graph_function = self._get_concrete_function_garbage_collected(
#    3071         *args, **kwargs)
#    3072     graph_function._garbage_collector.release()  # pylint: disable=protected-access
#
# c:\Users\Daniel Kuknyo\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    3034       args, kwargs = None, None
#    3035     with self._lock:
# -> 3036       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3037       seen_names = set()
#    3038       captured = object_identity.ObjectIdentitySet(
#
# c:\Users\Daniel Kuknyo\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3290
#    3291           self._function_cache.add_call_context(cache_key.call_context)
# -> 3292           graph_function = self._create_graph_function(args, kwargs)
#    3293           self._function_cache.add(cache_key, cache_key_deletion_observer,
#    3294                                    graph_function)
#
# c:\Users\Daniel Kuknyo\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3128     arg_names = base_arg_names + missing_arg_names
#    3129     graph_function = ConcreteFunction(
# -> 3130         func_graph_module.func_graph_from_py_func(
#    3131             self._name,
#    3132             self._python_function,
#
# c:\Users\Daniel Kuknyo\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1159         _, original_func = tf_decorator.unwrap(python_func)
#    1160
# -> 1161       func_outputs = python_func(*func_args, **func_kwargs)
#    1162
#    1163       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# c:\Users\Daniel Kuknyo\anaconda3\lib\site-packages\tensorflow\python\data\ops\structured_function.py in wrapped_fn(*args)
#     246           attributes=defun_kwargs)
#     247       def wrapped_fn(*args):  # pylint: disable=missing-docstring
# --> 248         ret = wrapper_helper(*args)
#     249         ret = structure.to_tensor_list(self._output_structure, ret)
#     250         return [ops.convert_to_tensor(t) for t in ret]
#
# c:\Users\Daniel Kuknyo\anaconda3\lib\site-packages\tensorflow\python\data\ops\structured_function.py in wrapper_helper(*args)
#     175       if not _should_unpack(nested_args):
#     176         nested_args = (nested_args,)
# --> 177       ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#     178       if _should_pack(ret):
#     179         ret = tuple(ret)
#
# c:\Users\Daniel Kuknyo\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py in wrapper(*args, **kwargs)
#     687       try:
#     688         with conversion_ctx:
# --> 689           return converted_call(f, args, kwargs, options=options)
#     690       except Exception as e:  # pylint:disable=broad-except
#     691         if hasattr(e, 'ag_error_metadata'):
#
# c:\Users\Daniel Kuknyo\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     375
#     376   if not options.user_requested and conversion.is_allowlisted(f):
# --> 377     return _call_unconverted(f, args, kwargs, options)
#     378
#     379   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# c:\Users\Daniel Kuknyo\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     456
#     457   if kwargs is not None:
# --> 458     return f(*args, **kwargs)
#     459   return f(*args)
#     460
#
# c:\Users\Daniel Kuknyo\anaconda3\lib\site-packages\keras\engine\data_adapter.py in slice_batch_indices(indices)
#     313           first_k_indices, [num_full_batches, batch_size])
#     314
# --> 315       flat_dataset = tf.data.Dataset.from_tensor_slices(first_k_indices)
#     316       if self._partial_batch_size:
#     317         index_remainder = tf.data.Dataset.from_tensors(tf.slice(
#
# c:\Users\Daniel Kuknyo\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in from_tensor_slices(tensors, name)
#     791       Dataset: A `Dataset`.
#     792     """
# --> 793     return TensorSliceDataset(tensors, name=name)
#     794
#     795   class _GeneratorState(object):
#
# c:\Users\Daniel Kuknyo\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __init__(self, element, is_files, name)
#    4493               tensor_shape.dimension_value(t.get_shape()[0])))
#    4494
# -> 4495     variant_tensor = gen_dataset_ops.tensor_slice_dataset(
#    4496         self._tensors,
#    4497         output_shapes=structure.get_flat_tensor_shapes(self._structure),
#
# c:\Users\Daniel Kuknyo\anaconda3\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py in tensor_slice_dataset(components, output_shapes, is_files, metadata, name)
#    7553     metadata = ""
#    7554   metadata = _execute.make_str(metadata, "metadata")
# -> 7555   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    7556         "TensorSliceDataset", components=components,
#    7557                               output_shapes=output_shapes, is_files=is_files,
#
# c:\Users\Daniel Kuknyo\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     738       # Add Op to graph
#     739       # pylint: disable=protected-access
# --> 740       op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     741                                  name=scope, input_types=input_types,
#     742                                  attrs=attr_protos, op_def=op_def)
#
# c:\Users\Daniel Kuknyo\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     691       inp = self.capture(inp)
#     692       captured_inputs.append(inp)
# --> 693     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     694         op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     695         compute_device)
#
# c:\Users\Daniel Kuknyo\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3774     # Session.run call cannot occur between creating and mutating the op.
#    3775     with self._mutation_lock():
# -> 3776       ret = Operation(
#    3777           node_def,
#    3778           self,
#
# c:\Users\Daniel Kuknyo\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    2169       if op_def is None:
#    2170         op_def = self._graph._get_op_def(node_def.op)
# -> 2171       self._c_op = _create_c_op(self._graph, node_def, inputs,
#    2172                                 control_input_ops, op_def)
#    2173       name = compat.as_str(node_def.name)
#
# c:\Users\Daniel Kuknyo\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\Daniel Kuknyo\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    2008
#    2009   try:
# -> 2010     c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    2011   except errors.InvalidArgumentError as e:
#    2012     # Convert to ValueError for backwards compatibility.
#
# KeyboardInterrupt:
